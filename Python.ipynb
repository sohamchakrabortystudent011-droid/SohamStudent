# %% [markdown]
# <a href="https://colab.research.google.com/github/sohamchakrabortystudent011-droid/SohamStudent/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 2.5
c = True
d = 'Soham'
e = None
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>

# %%
s1 = "Soham is a very god of programming"
print(s1)
print(s1.replace("very", "great"))
print(s1.find("v"))
print(len(s1))
print(s1.count("a"))
# Out:
# Soham is a very god of programming
# Soham is a great god of programming
# 11
# 34
# 3

# %%
print('''Dear Soham,
You are invited to my party
Thanks.''')
name = "Soham"
print(f"Dear {name},\nYou are invited to my party\nThanks.")
# Out:
# Dear Soham,
# You are invited to my party
# Thanks.
# Dear Soham,
# You are invited to my party
# Thanks.
